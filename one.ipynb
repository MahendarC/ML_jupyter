# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import csv
import time

# Base URL
base_url = "https://housing.com/in/buy/bangalore/bangalore"
headers = {'User-Agent': 'Mozilla/4.0 (compatible; MSIE 6.0; AOL 9.0; Windows NT 5.1; {}; Alawar 2.08; .NET CLR 1.0.3705)'}

# Initialize a list to store extracted data
extracted_data = []

# Function to process a single page
def process_page(url):
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch {url}")
        return
    
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Find all relevant anchor tags
    anchors = soup.find_all(
        "a", 
        {"data-q": "title", "class": "_j31f9d _c8dlk8 _g3l52n _csbfng _frwh2y T_e4485809 _ks15vq _vv1q9c _sq1l2s T_091c165f"}
    )
    
    # Iterate through each link
    for anchor in anchors:
        href = anchor.get("href")  # Relative link
        if not href:
            continue
        full_url = urljoin(base_url, href)  # Convert to absolute URL
        
        # Fetch the linked page
        linked_page_response = requests.get(full_url)
        if linked_page_response.status_code != 200:
            print(f"Failed to fetch {full_url}")
            continue
        
        linked_soup = BeautifulSoup(linked_page_response.content, "html.parser")
        print(f"Processing: {full_url}")
        
        # Extract the required data
        data = {}
        data["Location"] = linked_soup.find("div", class_="css-1ty5xzi").text.strip() if linked_soup.find("div", class_="css-1ty5xzi") else "No Location"
        data["Date of Listing"] = linked_soup.find("div", class_="css-1k19e3").text.strip() if linked_soup.find("div", class_="css-1k19e3") else "No Date"
        data["No. of Bedrooms"] = linked_soup.find("div", class_="css-1mtnl2n").text.strip() if linked_soup.find("div", class_="css-1mtnl2n") else "No Bedrooms"
        data["No. of Bathrooms"] = linked_soup.find("div", class_="bathrooms-class").text.strip() if linked_soup.find("div", class_="bathrooms-class") else "No Bathrooms"
        data["Area"] = linked_soup.find("li", class_="area-header-title active css-r25t52").text.strip() if linked_soup.find("li", class_="area-header-title active css-r25t52") else "No Area"
        data["Parking Availability"] = linked_soup.find("div", class_="T_5990d116 _1q731trj _6w1e54 _9scj1k _fycs5v _ks15vq _c81fwx _h3ftgi label").text.strip() if linked_soup.find("div", class_="T_5990d116 _1q731trj _6w1e54 _9scj1k _fycs5v _ks15vq _c81fwx _h3ftgi label") else "No Parking Info"
        data["Furnishing Status"] = linked_soup.find("div", class_="").text.strip() if linked_soup.find("div", class_="furnishing-class") else "No Furnishing Info"
        data["Apartment Name"] = linked_soup.find("h1", class_="css-1hidc9c").text.strip() if linked_soup.find("h1", class_="css-1hidc9c") else "No Apartment Name"
        data["Current Price"] = linked_soup.find("div", class_="css-yv0jp1").text.strip() if linked_soup.find("div", class_="css-yv0jp1") else "No Price"

        # Append to the data list
        extracted_data.append(data)
        
        # Introduce a delay to avoid overloading the server
        time.sleep(1)

# Pagination loop
page_number = 1
max_pages = 2  # Limit to 3 pages

while page_number <= max_pages:
    # Generate the URL for the current page
    page_url = f"{base_url}?page={page_number}"
    print(f"Fetching page {page_number}: {page_url}")
    
    # Process the page
    response = requests.get(page_url)
    if response.status_code != 200 or "No results found" in response.text:
        print("No more pages to process.")
        break
    
    process_page(page_url)
    page_number += 1



'''# Pagination loop
page_number = 1
while True:
    # Generate the URL for the current page
    page_url = f"{base_url}?page={page_number}"
    print(f"Fetching page {page_number}: {page_url}")
    
    # Process the page
    response = requests.get(page_url)
    if response.status_code != 200 or "No results found" in response.text:
        print("No more pages to process.")
        break
    
    process_page(page_url)
    page_number += 1
'''

# Save the data to a CSV file
csv_file = "scraped_data.csv"
with open(csv_file, "w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=["Location", "Date of Listing", "No. of Bedrooms", "No. of Bathrooms", "Area", "Parking Availability", "Furnishing Status", "Apartment Name", "Current Price"])
    writer.writeheader()
    writer.writerows(extracted_data)

print(f"Data saved to {csv_file}")
# Out:
# Fetching page 1: https://housing.com/in/buy/bangalore/bangalore?page=1
# Processing: https://housing.com/in/buy/projects/page/328018-serene-heights-by-modern-spaaces-in-kadagrahara
# Processing: https://housing.com/in/buy/projects/page/318558-ma-sarada-upavan-phase-ii-by-ma-sarada-constructions-bangalore-in-bommasandra
# Processing: https://housing.com/in/buy/projects/page/329608-sattva-songbird-by-sattva-group-in-aavalahalli
# Processing: https://housing.com/in/buy/projects/page/336167-embassy-verde-by-embassy-group-in-mahadeva-kodigehalli
# Processing: https://housing.com/in/buy/projects/page/288186-inspira-infinity-by-inspira-builders-in-carmelaram
# Processing: https://housing.com/in/buy/projects/page/332912-signature-heights-by-signature-dwellings-in-neraluru
# Processing: https://housing.com/in/buy/projects/page/329241-sumadhura-capitol-residences-by-sumadhura-infracon-pvt-ltd-in-whitefield
# Processing: https://housing.com/in/buy/projects/page/333007-konig-north-county-by-konig-homes-in-yelahanka
# Processing: https://housing.com/in/buy/projects/page/330575-aryan-1-celeste-by-aryan-landmarks-in-yelahanka-new-town
# Processing: https://housing.com/in/buy/projects/page/329613-sattva-lumina-by-sattva-group-in-rajanukunte
# Processing: https://housing.com/in/buy/projects/page/333796-global-edifice-legacy-by-global-edifice-builders-in-marsur
# Processing: https://housing.com/in/buy/projects/page/254459-olympia-by-gopalan-enterprises-in-kumbalgodu
# Processing: https://housing.com/in/buy/projects/page/286001-anand-somu-aarush-by-anand-group-builders-and-developers-in-jp-nagar
# Processing: https://housing.com/in/buy/projects/page/300364-grand-icon-3-by-iconhomz-in-bommasandra
# Processing: https://housing.com/in/buy/projects/page/37942-nikoo-homes-v-by-bhartiya-urban-private-limited-in-kannuru
# Processing: https://housing.com/in/buy/projects/page/313031-provident-botanico-by-provident-housing-limited-in-thirumalashettyhally
# Processing: https://housing.com/in/buy/projects/page/309924-provident-deansgate-by-provident-housing-limited-in-yelahanka
# Processing: https://housing.com/in/buy/projects/page/322054-sanjeevini-aarna-by-sanjeevini-group-in-kammavari-pete
# Processing: https://housing.com/in/buy/projects/page/1093-provident-sunworth-city-by-provident-housing-limited-in-kambipura
# Processing: https://housing.com/in/buy/projects/page/128013-sona-vistaas-by-sona-valliappa-group-in-akshayanagar
# Processing: https://housing.com/in/buy/projects/page/312393-concorde-antares-by-concorde-housing-corporation-pvt-ltd-in-vidyaranyapura
# Processing: https://housing.com/in/buy/projects/page/257746-ajmera-nucleus-by-ajmera-housing-corporation-bangalore-in-electronic-city-phase-2
# Processing: https://housing.com/in/buy/projects/page/309884-brigade-sanctuary-by-brigade-enterprises-ltd-in-hegondanahalli
# Processing: https://housing.com/in/buy/projects/page/322195-reliaable-the-downtown-phase-1-by-reliable-developers-in-rayasandra
# Processing: https://housing.com/in/buy/projects/page/312327-profound-lakeshore-by-profound-developers-in-jigani
# Processing: https://housing.com/in/buy/projects/page/317617-lvs-paradise-by-lvs-builders-developers-in-hallehalli
# Processing: https://housing.com/in/buy/projects/page/335488-ranka-ankura-by-ranka-international-private-limited-in-kannuru
# Processing: https://housing.com/in/buy/projects/page/297957-breeze-park-by-livvzo-infra-llp-in-anekal
# Processing: https://housing.com/in/buy/projects/page/311770-sattva-la-vita-by-sattva-group-in-kannuru
# Processing: https://housing.com/in/buy/projects/page/255342-dsr-elixir-by-dsr-infrastructure-pvt-ltd-in-whitefield
# Fetching page 2: https://housing.com/in/buy/bangalore/bangalore?page=2
# Processing: https://housing.com/in/buy/projects/page/171464-serene-gardens-by-jacobson-developers-in-hennur
# Processing: https://housing.com/in/buy/projects/page/308643-jr-eastfields-by-jr-housing-developers-pvt-ltd-in-hoskote
# Processing: https://housing.com/in/buy/projects/page/283108-keya-around-the-life-by-keya-homes-in-k-r-puram
# Processing: https://housing.com/in/buy/projects/page/60476-nitesh-long-island-by-nitesh-estates-in-binnamangala
# Processing: https://housing.com/in/buy/projects/page/235767-canvas-cove-by-assetz-property-group-in-begur
# Processing: https://housing.com/in/buy/projects/page/315009-assetz-66-shibui-by-assetz-property-group-in-whitefield
# Processing: https://housing.com/in/buy/projects/page/317633-sora-saki-by-assetz-property-group-in-gummanahalli
# Processing: https://housing.com/in/buy/projects/page/332470-bold-aspire-by-bold-developers-in-thimmadahalli
# Processing: https://housing.com/in/buy/projects/page/332219-sbr-one-residence-by-sbr-group-in-kadugodi
# Processing: https://housing.com/in/buy/projects/page/314323-unity-by-the-hills-by-unity-infrastructure-in-jayanagar
# Processing: https://housing.com/in/buy/projects/page/274607-sentient-eden-by-sentient-developers-in-kasavanahalli
# Processing: https://housing.com/in/buy/projects/page/324706-sai-prakruthi-nivasaa-by-sai-akshaya-ventures-in-hosahalli
# Processing: https://housing.com/in/buy/projects/page/318885-dwara-orville-by-dwara-developers-in-gottigere
# Processing: https://housing.com/in/buy/projects/page/321050-udbhav-gokulam-by-udbhav-builders-and-developers-in-balagere
# Processing: https://housing.com/in/buy/projects/page/287002-mathapathi-grand-field-by-mathapathi-constructions-pvt-ltd-in-gunjur
# Processing: https://housing.com/in/buy/projects/page/331205-keya-the-lake-terraes-by-keya-homes-in-electronic-city
# Processing: https://housing.com/in/buy/projects/page/330295-navins-antheia-poetry-by-navins-housing-properties-in-jp-nagar
# Processing: https://housing.com/in/buy/projects/page/332272-arohana-serenity-by-rohan-infra-builderrs-and-developerrs-in-kengeri
# Processing: https://housing.com/in/buy/projects/page/25954-keya-life-by-the-lake-by-keya-homes-in-jakkur
# Processing: https://housing.com/in/buy/projects/page/317933-casagrand-amor-by-casagrand-builder-private-limited-in-begur
# Processing: https://housing.com/in/buy/projects/page/3875-atz-areva-by-atz-properties-in-balagere
# Processing: https://housing.com/in/buy/projects/page/325971-tvs-isle-of-trees-by-tvs-emerald-haven-realty-in-jakkur
# Processing: https://housing.com/in/buy/projects/page/318935-axis-oaklyn-by-axis-concept-construction-ltd-in-yelahanka
# Processing: https://housing.com/in/buy/projects/page/310456-abhee-celestial-city-by-abhee-ventures-in-gunjur
# Processing: https://housing.com/in/buy/projects/page/331406-godrej-lakeside-orchard-by-godrej-properties-ltd-in-chikkakannalli
# Processing: https://housing.com/in/buy/projects/page/305798-birla-trimaya-phase-i-by-birla-estate-in-devanahalli
# Processing: https://housing.com/in/buy/projects/page/327950-godrej-yeshwanthpur-by-godrej-properties-ltd-in-yeswanthpur
# Processing: https://housing.com/in/buy/projects/page/334025-shriram-codename-smash-hit-by-shriram-properties-in-rajanukunte
# Processing: https://housing.com/in/buy/projects/page/305491-godrej-ananda-phase-iii-by-godrej-properties-ltd-in-bagalur
# Processing: https://housing.com/in/buy/projects/page/312599-dnr-parklink-phase-2-by-dnr-corporation-pvt-ltd-in-chikkagubbi-village
# Data saved to scraped_data.csv
